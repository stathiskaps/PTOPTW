# %%
import pandas as pd
import matplotlib.pyplot as plt

instance = 'pr10'
m = 2
caption = 'Figure 1: Comparison of score and execution time across s values for '+instance+', m='+str(m)
filename = instance+'_'+str(m)+'.csv'
# Load the data from CSV file
df = pd.read_csv(filename)

# Create a figure with two subplots
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

# Plot the score data in the first subplot
axs[0].plot(df['s'], df['score'])
axs[0].set_xlabel('s')
axs[0].set_ylabel('score')
axs[0].set_title('Score plot')

# Plot the execution time data in the second subplot
axs[1].plot(df['s'], df['time'])
axs[1].set_xlabel('s')
axs[1].set_ylabel('time (s)')
axs[1].set_title('Execution time plot')

axs[0].set_xticks(df['s'].unique())
axs[1].set_xticks(df['s'].unique())

# fig.text(0.5, 0.00000001, caption, ha='center', fontsize=12)

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()

# Save the figure
fig.savefig('plot.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

instance = 'pr10'
m = 2
caption = 'Figure 1: Comparison of score and execution time across s values for '+instance+', m='+str(m)

# Load the data from CSV files
filename1 = 'release/'+instance+'_'+str(m)+'.csv'
filename2 = 'release-no-history/'+instance+'_'+str(m)+'.csv'
df1 = pd.read_csv(filename1)
df2 = pd.read_csv(filename2)

# Create a figure with two subplots
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

# Plot the score data in the first subplot
axs[0].plot(df1['s'], df1['score'], label='release')
axs[0].plot(df2['s'], df2['score'], label='release-no-history')
axs[0].set_xlabel('s')
axs[0].set_ylabel('score')
axs[0].set_title('Score plot')
axs[0].legend()

# Plot the execution time data in the second subplot
axs[1].plot(df1['s'], df1['time'], label='release')
axs[1].plot(df2['s'], df2['time'], label='release-no-history')
axs[1].set_xlabel('s')
axs[1].set_ylabel('time (s)')
axs[1].set_title('Execution time plot')
axs[1].legend()

axs[0].set_xticks(df1['s'].unique())
axs[1].set_xticks(df1['s'].unique())

# fig.text(0.5, 0.00000001, caption, ha='center', fontsize=12)

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()

# Save the figure
fig.savefig('plot.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

instance = 'pr20'
for m in range(1, 5):
    caption = 'Figure 1: Comparison of score and execution time across s values for '+instance+', m='+str(m)
    
    # Load the data from CSV files
    filename1 = 'aws/release/'+instance+'_'+str(m)+'.csv'
    filename2 = 'aws/release-no-history/'+instance+'_'+str(m)+'.csv'
    filename3 = 'aws/release-simple-intervals/'+instance+'_'+str(m)+'.csv'
    filename4 = 'aws/release-no-improvements/'+instance+'_'+str(m)+'.csv'
    df1 = pd.read_csv(filename1)
    df2 = pd.read_csv(filename2)
    df3 = pd.read_csv(filename3)
    df4 = pd.read_csv(filename4)

    # Create a figure with two subplots
    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

    # Plot the score data in the first subplot
    axs[0].plot(df1['s'], df1['score'], label='release')
    axs[0].plot(df2['s'], df2['score'], label='no-history')
    axs[0].plot(df3['s'], df3['score'], label='equal-intervals')
    axs[0].plot(df4['s'], df4['score'], label='no-improvements')
    axs[0].set_xlabel('s')
    axs[0].set_ylabel('score')
    axs[0].set_title('Score plot')
    axs[0].legend()

    # Plot the execution time data in the second subplot
    axs[1].plot(df1['s'], df1['time'], label='release')
    axs[1].plot(df2['s'], df2['time'], label='no-history')
    axs[1].plot(df3['s'], df3['time'], label='equal-intervals')
    axs[1].plot(df4['s'], df4['time'], label='no-improvements')
    axs[1].set_xlabel('s')
    axs[1].set_ylabel('time (s)')
    axs[1].set_title('Execution time plot')
    axs[1].legend()

    axs[0].set_xticks(df1['s'].unique())
    axs[1].set_xticks(df1['s'].unique())
    
    axs[0].set_xticks(df2['s'].unique())
    axs[1].set_xticks(df2['s'].unique())
    
    axs[0].set_xticks(df3['s'].unique())
    axs[1].set_xticks(df3['s'].unique())
    
    axs[0].set_xticks(df4['s'].unique())
    axs[1].set_xticks(df4['s'].unique())

    # Set a title for the entire figure that includes the value of m
    fig.suptitle('Comparison of release and release-no-history for m = '+str(m), fontsize=14)

    # Adjust the spacing between subplots
    fig.tight_layout()

    # Show the plot
    plt.show()

    # Save the figure
    fig.savefig('plot_m'+str(m)+'.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

fig, axs = plt.subplots(4, 2)
axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0, 0]')
axs[0, 1].plot(x, y, 'tab:orange')
axs[0, 1].set_title('Axis [0, 1]')
axs[1, 0].plot(x, -y, 'tab:green')
axs[1, 0].set_title('Axis [1, 0]')
axs[1, 1].plot(x, -y, 'tab:red')
axs[1, 1].set_title('Axis [1, 1]')

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %%
import pandas as pd
import matplotlib.pyplot as plt

instance = 'pr20'
caption = caption = 'Figure 1: Comparison of score and execution time across s values for '+instance+', m='+str(m)

# Create a figure with two subplots
fig, axs = plt.subplots(4, 2, figsize=(10, 16))

for m in range(0, 4):
    
    # Load the data from CSV files
    filename1 = 'aws/release/'+instance+'_'+str(m+1)+'.csv'
    filename2 = 'aws/release-no-history/'+instance+'_'+str(m+1)+'.csv'
    filename3 = 'aws/release-simple-intervals/'+instance+'_'+str(m+1)+'.csv'
    filename4 = 'aws/release-no-improvements/'+instance+'_'+str(m+1)+'.csv'
    df1 = pd.read_csv(filename1)
    df2 = pd.read_csv(filename2)
    df3 = pd.read_csv(filename3)
    df4 = pd.read_csv(filename4)
    
    print(df1)
    
    # Plot the score data in the first subplot
    axs[m, 0].plot(df1['s'], df1['score'], label='release')
    axs[m, 0].plot(df2['s'], df2['score'], label='no-history')
    axs[m, 0].plot(df3['s'], df3['score'], label='equal-intervals')
    axs[m, 0].plot(df4['s'], df4['score'], label='no-improvements')
    axs[m, 0].set_xlabel('s')
    axs[m, 0].set_ylabel('score')
    axs[m, 0].set_title('Score plot')
    axs[m, 0].legend()

    # Plot the execution time data in the second subplot
    axs[m, 1].plot(df1['s'], df1['time'], label='release')
    axs[m, 1].plot(df2['s'], df2['time'], label='no-history')
    axs[m, 1].plot(df3['s'], df3['time'], label='equal-intervals')
    axs[m, 1].plot(df4['s'], df4['time'], label='no-improvements')
    axs[m, 1].set_xlabel('s')
    axs[m, 1].set_ylabel('time (s)')
    axs[m, 1].set_title('Execution time plot')
    axs[m, 1].legend()
    
    axs[].set(xlabel='x-label', ylabel='y-label')

    axs[m, 0].set_xticks(df1['s'].unique())
    axs[m, 1].set_xticks(df1['s'].unique())
    
    axs[m, 0].set_xticks(df2['s'].unique())
    axs[m, 1].set_xticks(df2['s'].unique())
    
    axs[m, 0].set_xticks(df3['s'].unique())
    axs[m, 1].set_xticks(df3['s'].unique())
    
    axs[m, 0].set_xticks(df4['s'].unique())
    axs[m, 1].set_xticks(df4['s'].unique())

# # Set a title for the entire figure that includes the value of m
# fig.suptitle('Comparison of release and release-no-history for m = '+str(m), fontsize=14)

# # Hide x labels and tick labels for top plots and y ticks for right plots.
# for ax in axs.flat:
#     ax.label_outer()

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()

# Save the figure
fig.savefig('plot_m'+str(m)+'.png')
# Out:
#    s  score   time
# 0  1    610  2.295
# 1  2    586  1.886
# 2  3    534  0.658
# 3  4    556  0.923
#    s  score   time
# 0  1   1109  5.483
# 1  2   1084  1.921
# 2  3    996  1.195
# 3  4    999  1.274
#    s  score   time
# 0  1   1534  4.719
# 1  2   1509  2.601
# 2  3   1454  2.841
# 3  4   1376  1.308
#    s  score   time
# 0  1   1979  8.921
# 1  2   1873  3.954
# 2  3   1792  1.988
# 3  4   1720  2.147
